# %%
# !apt install swig cmake ffmpeg xvfb python3-opengl
# !pip install stable-baselines3==2.0.0a5 gymnasium[box2d] huggingface_sb3 pyvirtualdisplay imageio[ffmpeg]
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-opengl is already the newest version (3.1.5+dfsg-1).
# swig is already the newest version (4.0.2-1ubuntu1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.8).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Requirement already satisfied: stable-baselines3==2.0.0a5 in /usr/local/lib/python3.10/dist-packages (2.0.0a5)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: huggingface_sb3 in /usr/local/lib/python3.10/dist-packages (3.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (3.0)
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.10/dist-packages (2.31.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (1.25.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (2.2.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame==2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.1.3)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.2.1)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (0.20.3)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (6.0.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.1.2)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio[ffmpeg]) (9.4.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from imageio[ffmpeg]) (0.4.9)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from imageio[ffmpeg]) (5.9.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.66.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->stable-baselines3==2.0.0a5) (12.4.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg->imageio[ffmpeg]) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3==2.0.0a5) (1.3.0)

# %%
import os
os.kill(os.getpid(), 9)

# %%
from pyvirtualdisplay import Display
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gymnasium as gym
env = gym.make("BipedalWalker-v3", hardcore=True)
env.reset()
# Out:
# (array([ 2.7475406e-03, -2.0650282e-06,  1.6065684e-04, -1.5999984e-02,
#          9.2122972e-02, -2.1201676e-04,  8.6017501e-01,  1.5599747e-03,
#          1.0000000e+00,  3.2527719e-02, -2.1199802e-04,  8.5372543e-01,
#          1.4993631e-04,  1.0000000e+00,  4.4081393e-01,  4.4582003e-01,
#          4.6142268e-01,  4.8955008e-01,  5.3410268e-01,  6.0246092e-01,
#          7.0914876e-01,  8.8593167e-01,  1.0000000e+00,  1.0000000e+00],
#        dtype=float32),
#  {})

# %%
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (24,)
# Sample observation [-2.7890325  -0.36153117 -3.5301142  -0.3197522   2.9382448   1.3352026
#  -1.7200413  -1.4780458   2.2080905  -1.9223825   1.6878897  -0.856083
#  -3.0281463   0.09583899 -0.48850304  0.20496143  0.00905617 -0.13050555
#  -0.09322756  0.869291   -0.29302204  0.12171899 -0.79148537  0.7153006 ]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.shape)
print("Action Space Sample", env.action_space.sample())
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape (4,)
# Action Space Sample [ 0.33917123 -0.9469362   0.5420178   0.23178801]

# %%
from stable_baselines3.common.env_util import make_vec_env
env = make_vec_env('BipedalWalker-v3', n_envs=1)

# %%
from stable_baselines3 import DDPG  # Change this line
model = DDPG(  # Change this line
    policy = 'MlpPolicy',
    env = env,
    learning_rate=1e-3,  # Example hyperparameters for DDPG
    buffer_size=100000,
    batch_size=64,
    learning_starts=10000,
    tau=0.005,
    gamma=0.99,
    verbose=1
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Using cuda device

# %%
from wasabi import Printer
import numpy as np
from stable_baselines3.common.base_class import BaseAlgorithm
from pathlib import Path
import tempfile
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import (
    DummyVecEnv,
    VecEnv,
    VecVideoRecorder,
)

# %%
msg = Printer()

# %%
def generate_replay(
    model: BaseAlgorithm,
    eval_env: VecEnv,
    video_length: int,
    is_deterministic: bool,
    local_path: Path,
):
    """
    Generate a replay video of the agent
    :param model: trained model
    :param eval_env: environment used to evaluate the agent
    :param video_length: length of the video (in timesteps)
    :param is_deterministic: use deterministic or stochastic actions
    :param local_path: path of the local repository
    """
    # This is another temporary directory for video outputs
    # SB3 created a -step-0-to-... meta files as well as other
    # artifacts which we don't want in the repo.
    with tempfile.TemporaryDirectory() as tmpdirname:
        # Step 1: Create the VecVideoRecorder
        env = VecVideoRecorder(
            eval_env,
            tmpdirname,
            record_video_trigger=lambda x: x == 0,
            video_length=video_length,
            name_prefix="",
        )

        obs = env.reset()
        lstm_states = None
        episode_starts = np.ones((env.num_envs,), dtype=bool)

        try:
            for _ in range(video_length):
                action, lstm_states = model.predict(
                    obs,
                    state=lstm_states,
                    episode_start=episode_starts,
                    deterministic=is_deterministic,
                )
                obs, _, episode_starts, _ = env.step(action)

            # Save the video
            env.close()

            # Convert the video with x264 codec
            inp = env.video_recorder.path
            out = local_path
            os.system(f"ffmpeg -y -i {inp} -vcodec h264 {out}".format(inp, out))
            print(f"Video saved to: {out}")
        except KeyboardInterrupt:
            pass
        except Exception as e:
            msg.fail(str(e))
            # Add a message for video
            msg.fail(
                "We are unable to generate a replay of your agent"
            )

# %%
model.learn(total_timesteps=580000)

# Save the model
model_name = "ddpg-BipedalWalker-v3"  # Adjust model name if needed
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 837      |
# |    ep_rew_mean     | -96.2    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 2327     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3347     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 839      |
# |    ep_rew_mean     | -97.1    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 2299     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 6714     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 846      |
# |    ep_rew_mean     | -96      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 1549     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 10148    |
# | train/             |          |
# |    actor_loss      | -0.114   |
# |    critic_loss     | 4.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 101      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 662      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 1113     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 10598    |
# | train/             |          |
# |    actor_loss      | 0.222    |
# |    critic_loss     | 3.88     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 579      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 945      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 10876    |
# | train/             |          |
# |    actor_loss      | 0.143    |
# |    critic_loss     | 12.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 895      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 534      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 477      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 12828    |
# | train/             |          |
# |    actor_loss      | 0.0821   |
# |    critic_loss     | 3.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2871     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 466      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 459      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 13036    |
# | train/             |          |
# |    actor_loss      | 0.0895   |
# |    critic_loss     | 2.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3080     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 413      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 436      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 13204    |
# | train/             |          |
# |    actor_loss      | 0.24     |
# |    critic_loss     | 1.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3247     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 453      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 14989    |
# | train/             |          |
# |    actor_loss      | 0.312    |
# |    critic_loss     | 2.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3475     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | -117     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 332      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 18413    |
# | train/             |          |
# |    actor_loss      | -0.154   |
# |    critic_loss     | 1.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 425      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 283      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 18710    |
# | train/             |          |
# |    actor_loss      | -2.42    |
# |    critic_loss     | 2.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8723     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 396      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 279      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 19002    |
# | train/             |          |
# |    actor_loss      | -2.65    |
# |    critic_loss     | 1.22     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9028     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 370      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 276      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 19256    |
# | train/             |          |
# |    actor_loss      | -2.41    |
# |    critic_loss     | 3.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9279     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 376      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 290      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 21062    |
# | train/             |          |
# |    actor_loss      | -2.59    |
# |    critic_loss     | 2.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9548     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 355      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 256      |
# |    time_elapsed    | 83       |
# |    total_timesteps | 21326    |
# | train/             |          |
# |    actor_loss      | -3.55    |
# |    critic_loss     | 2.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11345    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 364      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 241      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 23322    |
# | train/             |          |
# |    actor_loss      | -4.21    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13354    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 346      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 239      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 23551    |
# | train/             |          |
# |    actor_loss      | -4.5     |
# |    critic_loss     | 0.672    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13587    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 330      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 238      |
# |    time_elapsed    | 99       |
# |    total_timesteps | 23754    |
# | train/             |          |
# |    actor_loss      | -4.62    |
# |    critic_loss     | 3.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13802    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 237      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 24005    |
# | train/             |          |
# |    actor_loss      | -4.57    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14029    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 303      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 235      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 24247    |
# | train/             |          |
# |    actor_loss      | -4.62    |
# |    critic_loss     | 1.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14283    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 291      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 234      |
# |    time_elapsed    | 104      |
# |    total_timesteps | 24475    |
# | train/             |          |
# |    actor_loss      | -4.77    |
# |    critic_loss     | 1.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14510    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 235      |
# |    time_elapsed    | 106      |
# |    total_timesteps | 25143    |
# | train/             |          |
# |    actor_loss      | -4.79    |
# |    critic_loss     | 1.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14767    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 223      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 26950    |
# | train/             |          |
# |    actor_loss      | -4.71    |
# |    critic_loss     | 2.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16973    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 222      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 27197    |
# | train/             |          |
# |    actor_loss      | -4.87    |
# |    critic_loss     | 1.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17220    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 216      |
# |    time_elapsed    | 134      |
# |    total_timesteps | 29035    |
# | train/             |          |
# |    actor_loss      | -5.47    |
# |    critic_loss     | 1.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 261      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 215      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 29472    |
# | train/             |          |
# |    actor_loss      | -5.91    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19468    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 213      |
# |    time_elapsed    | 139      |
# |    total_timesteps | 29780    |
# | train/             |          |
# |    actor_loss      | -5.76    |
# |    critic_loss     | 1.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19803    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 212      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 30080    |
# | train/             |          |
# |    actor_loss      | -5.72    |
# |    critic_loss     | 0.987    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20086    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 211      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 30379    |
# | train/             |          |
# |    actor_loss      | -5.7     |
# |    critic_loss     | 3.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20404    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 211      |
# |    time_elapsed    | 145      |
# |    total_timesteps | 30675    |
# | train/             |          |
# |    actor_loss      | -5.54    |
# |    critic_loss     | 0.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20657    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 211      |
# |    time_elapsed    | 148      |
# |    total_timesteps | 31299    |
# | train/             |          |
# |    actor_loss      | -5.22    |
# |    critic_loss     | 1.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21139    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 205      |
# |    time_elapsed    | 161      |
# |    total_timesteps | 33121    |
# | train/             |          |
# |    actor_loss      | -6.62    |
# |    critic_loss     | 0.979    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23142    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 201      |
# |    time_elapsed    | 173      |
# |    total_timesteps | 35029    |
# | train/             |          |
# |    actor_loss      | -6.49    |
# |    critic_loss     | 1.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25018    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 219      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 198      |
# |    time_elapsed    | 185      |
# |    total_timesteps | 36883    |
# | train/             |          |
# |    actor_loss      | -7.58    |
# |    critic_loss     | 1.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26841    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 201      |
# |    time_elapsed    | 199      |
# |    total_timesteps | 40212    |
# | train/             |          |
# |    actor_loss      | -8.38    |
# |    critic_loss     | 1.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28698    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 265      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 188      |
# |    time_elapsed    | 240      |
# |    total_timesteps | 45199    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 1.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35098    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 187      |
# |    time_elapsed    | 243      |
# |    total_timesteps | 45596    |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 1.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35598    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 186      |
# |    time_elapsed    | 246      |
# |    total_timesteps | 46060    |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 1.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 254      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 186      |
# |    time_elapsed    | 249      |
# |    total_timesteps | 46458    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 1.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36467    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 254      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 186      |
# |    time_elapsed    | 250      |
# |    total_timesteps | 46731    |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 1.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36752    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 186      |
# |    time_elapsed    | 253      |
# |    total_timesteps | 47128    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 2.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37128    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 255      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 190      |
# |    time_elapsed    | 257      |
# |    total_timesteps | 49042    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 2.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37528    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 183      |
# |    time_elapsed    | 275      |
# |    total_timesteps | 50547    |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 3.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 40498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 185      |
# |    time_elapsed    | 301      |
# |    total_timesteps | 55852    |
# | train/             |          |
# |    actor_loss      | -19      |
# |    critic_loss     | 2.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44338    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 380      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 181      |
# |    time_elapsed    | 343      |
# |    total_timesteps | 62252    |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 2.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 50738    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 179      |
# |    time_elapsed    | 370      |
# |    total_timesteps | 66389    |
# | train/             |          |
# |    actor_loss      | -26.3    |
# |    critic_loss     | 2.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 54875    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 462      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 173      |
# |    time_elapsed    | 410      |
# |    total_timesteps | 71351    |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 2.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61275    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 484      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 175      |
# |    time_elapsed    | 428      |
# |    total_timesteps | 75309    |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 1.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63795    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 517      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 171      |
# |    time_elapsed    | 459      |
# |    total_timesteps | 78902    |
# | train/             |          |
# |    actor_loss      | -28.1    |
# |    critic_loss     | 2.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 68754    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 503      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 171      |
# |    time_elapsed    | 462      |
# |    total_timesteps | 79371    |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 8.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 69328    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 510      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 171      |
# |    time_elapsed    | 469      |
# |    total_timesteps | 80433    |
# | train/             |          |
# |    actor_loss      | -27.7    |
# |    critic_loss     | 2.63     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 70358    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 513      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 171      |
# |    time_elapsed    | 473      |
# |    total_timesteps | 81046    |
# | train/             |          |
# |    actor_loss      | -28      |
# |    critic_loss     | 3.52     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 71045    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 173      |
# |    time_elapsed    | 487      |
# |    total_timesteps | 84437    |
# | train/             |          |
# |    actor_loss      | -27.7    |
# |    critic_loss     | 2.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 72923    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 560      |
# |    ep_rew_mean     | -125     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 169      |
# |    time_elapsed    | 508      |
# |    total_timesteps | 86366    |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 3.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76391    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 591      |
# |    ep_rew_mean     | -125     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 169      |
# |    time_elapsed    | 530      |
# |    total_timesteps | 89731    |
# | train/             |          |
# |    actor_loss      | -31.5    |
# |    critic_loss     | 2.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79718    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 634      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 170      |
# |    time_elapsed    | 554      |
# |    total_timesteps | 94721    |
# | train/             |          |
# |    actor_loss      | -33.1    |
# |    critic_loss     | 1.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83207    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 624      |
# |    ep_rew_mean     | -125     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 168      |
# |    time_elapsed    | 567      |
# |    total_timesteps | 95519    |
# | train/             |          |
# |    actor_loss      | -32.8    |
# |    critic_loss     | 2.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 85398    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 627      |
# |    ep_rew_mean     | -126     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 168      |
# |    time_elapsed    | 581      |
# |    total_timesteps | 97718    |
# | train/             |          |
# |    actor_loss      | -32.5    |
# |    critic_loss     | 2.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87588    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | -126     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 167      |
# |    time_elapsed    | 586      |
# |    total_timesteps | 98451    |
# | train/             |          |
# |    actor_loss      | -32.3    |
# |    critic_loss     | 1.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 88364    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 615      |
# |    ep_rew_mean     | -127     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 167      |
# |    time_elapsed    | 606      |
# |    total_timesteps | 101754   |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 1.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 605      |
# |    ep_rew_mean     | -128     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 168      |
# |    time_elapsed    | 625      |
# |    total_timesteps | 105724   |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 2.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 94210    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 611      |
# |    ep_rew_mean     | -129     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 166      |
# |    time_elapsed    | 640      |
# |    total_timesteps | 106660   |
# | train/             |          |
# |    actor_loss      | -30.6    |
# |    critic_loss     | 2.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 96634    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 618      |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 166      |
# |    time_elapsed    | 648      |
# |    total_timesteps | 107835   |
# | train/             |          |
# |    actor_loss      | -29.8    |
# |    critic_loss     | 2.45     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97823    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 631      |
# |    ep_rew_mean     | -131     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 166      |
# |    time_elapsed    | 659      |
# |    total_timesteps | 109536   |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 2.68     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99508    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 648      |
# |    ep_rew_mean     | -131     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 165      |
# |    time_elapsed    | 672      |
# |    total_timesteps | 111504   |
# | train/             |          |
# |    actor_loss      | -28.7    |
# |    critic_loss     | 3.22     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 101484   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 678      |
# |    ep_rew_mean     | -131     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 165      |
# |    time_elapsed    | 694      |
# |    total_timesteps | 114946   |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 3.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 104844   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 670      |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 165      |
# |    time_elapsed    | 700      |
# |    total_timesteps | 116084   |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 2.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 105892   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 669      |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 165      |
# |    time_elapsed    | 710      |
# |    total_timesteps | 117468   |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 3.31     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 107394   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 634      |
# |    ep_rew_mean     | -128     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 165      |
# |    time_elapsed    | 720      |
# |    total_timesteps | 119214   |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 2.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 108899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 622      |
# |    ep_rew_mean     | -126     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 165      |
# |    time_elapsed    | 754      |
# |    total_timesteps | 124478   |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 2.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 114100   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 164      |
# |    time_elapsed    | 788      |
# |    total_timesteps | 129735   |
# | train/             |          |
# |    actor_loss      | -27.1    |
# |    critic_loss     | 2.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 119364   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 625      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 165      |
# |    time_elapsed    | 808      |
# |    total_timesteps | 133840   |
# | train/             |          |
# |    actor_loss      | -26.4    |
# |    critic_loss     | 1.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 122326   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 605      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 163      |
# |    time_elapsed    | 829      |
# |    total_timesteps | 135762   |
# | train/             |          |
# |    actor_loss      | -25.5    |
# |    critic_loss     | 2.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 125664   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 586      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 163      |
# |    time_elapsed    | 838      |
# |    total_timesteps | 137479   |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 2.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127042   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 587      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 163      |
# |    time_elapsed    | 843      |
# |    total_timesteps | 138025   |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 1.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127917   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 615      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 164      |
# |    time_elapsed    | 861      |
# |    total_timesteps | 141887   |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 6.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 130373   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 632      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 162      |
# |    time_elapsed    | 885      |
# |    total_timesteps | 144228   |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 2.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 134235   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 611      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 163      |
# |    time_elapsed    | 892      |
# |    total_timesteps | 145518   |
# | train/             |          |
# |    actor_loss      | -25      |
# |    critic_loss     | 2.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135411   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 601      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 163      |
# |    time_elapsed    | 898      |
# |    total_timesteps | 146442   |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 2.49     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 136190   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 607      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 162      |
# |    time_elapsed    | 924      |
# |    total_timesteps | 150384   |
# | train/             |          |
# |    actor_loss      | -26      |
# |    critic_loss     | 1.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 140353   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 590      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 162      |
# |    time_elapsed    | 946      |
# |    total_timesteps | 153726   |
# | train/             |          |
# |    actor_loss      | -25.4    |
# |    critic_loss     | 2.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 585      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 162      |
# |    time_elapsed    | 948      |
# |    total_timesteps | 154002   |
# | train/             |          |
# |    actor_loss      | -25.2    |
# |    critic_loss     | 3.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144025   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 565      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 162      |
# |    time_elapsed    | 950      |
# |    total_timesteps | 154259   |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 1.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144281   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 561      |
# |    ep_rew_mean     | -120     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 162      |
# |    time_elapsed    | 951      |
# |    total_timesteps | 154539   |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 1.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144537   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 162      |
# |    time_elapsed    | 963      |
# |    total_timesteps | 156329   |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 1.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146370   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 510      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 162      |
# |    time_elapsed    | 965      |
# |    total_timesteps | 156682   |
# | train/             |          |
# |    actor_loss      | -25.7    |
# |    critic_loss     | 1.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146669   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 504      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 162      |
# |    time_elapsed    | 968      |
# |    total_timesteps | 157029   |
# | train/             |          |
# |    actor_loss      | -25.5    |
# |    critic_loss     | 4.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147029   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 496      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 162      |
# |    time_elapsed    | 970      |
# |    total_timesteps | 157391   |
# | train/             |          |
# |    actor_loss      | -25.5    |
# |    critic_loss     | 2.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147390   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 515      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 163      |
# |    time_elapsed    | 985      |
# |    total_timesteps | 161019   |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 3.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 149505   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 531      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 163      |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 164572   |
# | train/             |          |
# |    actor_loss      | -29.6    |
# |    critic_loss     | 2.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 153058   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 527      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 162      |
# |    time_elapsed    | 1033     |
# |    total_timesteps | 167670   |
# | train/             |          |
# |    actor_loss      | -31.1    |
# |    critic_loss     | 2.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 157024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 550      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 162      |
# |    time_elapsed    | 1050     |
# |    total_timesteps | 171111   |
# | train/             |          |
# |    actor_loss      | -30.7    |
# |    critic_loss     | 2.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 159597   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 542      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 161      |
# |    time_elapsed    | 1062     |
# |    total_timesteps | 171667   |
# | train/             |          |
# |    actor_loss      | -30.8    |
# |    critic_loss     | 3.22     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 161652   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 532      |
# |    ep_rew_mean     | -103     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 161      |
# |    time_elapsed    | 1066     |
# |    total_timesteps | 172449   |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 1.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 162222   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 505      |
# |    ep_rew_mean     | -103     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 161      |
# |    time_elapsed    | 1081     |
# |    total_timesteps | 174936   |
# | train/             |          |
# |    actor_loss      | -30.5    |
# ...
# |    actor_loss      | -59.8    |
# |    critic_loss     | 4.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 517377   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 420      |
# |    ep_rew_mean     | -79.7    |
# | time/              |          |
# |    episodes        | 1156     |
# |    fps             | 156      |
# |    time_elapsed    | 3410     |
# |    total_timesteps | 533175   |
# | train/             |          |
# |    actor_loss      | -56.7    |
# |    critic_loss     | 3.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 523167   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 417      |
# |    ep_rew_mean     | -81      |
# | time/              |          |
# |    episodes        | 1160     |
# |    fps             | 156      |
# |    time_elapsed    | 3413     |
# |    total_timesteps | 533498   |
# | train/             |          |
# |    actor_loss      | -56.3    |
# |    critic_loss     | 4.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 523500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 452      |
# |    ep_rew_mean     | -85.8    |
# | time/              |          |
# |    episodes        | 1164     |
# |    fps             | 156      |
# |    time_elapsed    | 3436     |
# |    total_timesteps | 538372   |
# | train/             |          |
# |    actor_loss      | -53.7    |
# |    critic_loss     | 4.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 526858   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 449      |
# |    ep_rew_mean     | -86.7    |
# | time/              |          |
# |    episodes        | 1168     |
# |    fps             | 156      |
# |    time_elapsed    | 3449     |
# |    total_timesteps | 539060   |
# | train/             |          |
# |    actor_loss      | -50.5    |
# |    critic_loss     | 3.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 529072   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 440      |
# |    ep_rew_mean     | -97.4    |
# | time/              |          |
# |    episodes        | 1172     |
# |    fps             | 156      |
# |    time_elapsed    | 3461     |
# |    total_timesteps | 540873   |
# | train/             |          |
# |    actor_loss      | -49.1    |
# |    critic_loss     | 4.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 530886   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 1176     |
# |    fps             | 156      |
# |    time_elapsed    | 3467     |
# |    total_timesteps | 541757   |
# | train/             |          |
# |    actor_loss      | -47.5    |
# |    critic_loss     | 4        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 531782   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 397      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 1180     |
# |    fps             | 156      |
# |    time_elapsed    | 3470     |
# |    total_timesteps | 542479   |
# | train/             |          |
# |    actor_loss      | -46.2    |
# |    critic_loss     | 5.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 532353   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 399      |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    episodes        | 1184     |
# |    fps             | 156      |
# |    time_elapsed    | 3479     |
# |    total_timesteps | 543908   |
# | train/             |          |
# |    actor_loss      | -45.7    |
# |    critic_loss     | 3.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 533590   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 1188     |
# |    fps             | 156      |
# |    time_elapsed    | 3484     |
# |    total_timesteps | 544541   |
# | train/             |          |
# |    actor_loss      | -44.7    |
# |    critic_loss     | 3.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 534490   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 412      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 1192     |
# |    fps             | 156      |
# |    time_elapsed    | 3492     |
# |    total_timesteps | 546576   |
# | train/             |          |
# |    actor_loss      | -44.2    |
# |    critic_loss     | 5.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 535510   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 1196     |
# |    fps             | 156      |
# |    time_elapsed    | 3530     |
# |    total_timesteps | 551722   |
# | train/             |          |
# |    actor_loss      | -41.5    |
# |    critic_loss     | 4.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 541462   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 461      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 156      |
# |    time_elapsed    | 3544     |
# |    total_timesteps | 553827   |
# | train/             |          |
# |    actor_loss      | -40      |
# |    critic_loss     | 4.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 543673   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 477      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 1204     |
# |    fps             | 156      |
# |    time_elapsed    | 3550     |
# |    total_timesteps | 555869   |
# | train/             |          |
# |    actor_loss      | -38.6    |
# |    critic_loss     | 3.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 544355   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 461      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 1208     |
# |    fps             | 156      |
# |    time_elapsed    | 3572     |
# |    total_timesteps | 559226   |
# | train/             |          |
# |    actor_loss      | -38.3    |
# |    critic_loss     | 3.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 547712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 425      |
# |    ep_rew_mean     | -103     |
# | time/              |          |
# |    episodes        | 1212     |
# |    fps             | 156      |
# |    time_elapsed    | 3592     |
# |    total_timesteps | 561046   |
# | train/             |          |
# |    actor_loss      | -37.9    |
# |    critic_loss     | 4.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 551064   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 441      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 1216     |
# |    fps             | 156      |
# |    time_elapsed    | 3604     |
# |    total_timesteps | 563026   |
# | train/             |          |
# |    actor_loss      | -37.7    |
# |    critic_loss     | 4.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 552862   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 450      |
# |    ep_rew_mean     | -99.3    |
# | time/              |          |
# |    episodes        | 1220     |
# |    fps             | 156      |
# |    time_elapsed    | 3611     |
# |    total_timesteps | 564104   |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 3.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 553943   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 457      |
# |    ep_rew_mean     | -97.7    |
# | time/              |          |
# |    episodes        | 1224     |
# |    fps             | 156      |
# |    time_elapsed    | 3617     |
# |    total_timesteps | 565003   |
# | train/             |          |
# |    actor_loss      | -37.4    |
# |    critic_loss     | 3.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 554835   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 461      |
# |    ep_rew_mean     | -96.6    |
# | time/              |          |
# |    episodes        | 1228     |
# |    fps             | 156      |
# |    time_elapsed    | 3621     |
# |    total_timesteps | 565557   |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 6.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 555364   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 463      |
# |    ep_rew_mean     | -96      |
# | time/              |          |
# |    episodes        | 1232     |
# |    fps             | 156      |
# |    time_elapsed    | 3624     |
# |    total_timesteps | 565947   |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 3.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 555966   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 469      |
# |    ep_rew_mean     | -94.4    |
# | time/              |          |
# |    episodes        | 1236     |
# |    fps             | 156      |
# |    time_elapsed    | 3629     |
# |    total_timesteps | 566661   |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 4.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 556692   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 471      |
# |    ep_rew_mean     | -94      |
# | time/              |          |
# |    episodes        | 1240     |
# |    fps             | 156      |
# |    time_elapsed    | 3631     |
# |    total_timesteps | 567006   |
# | train/             |          |
# |    actor_loss      | -35.6    |
# |    critic_loss     | 8.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 556981   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 471      |
# |    ep_rew_mean     | -93.6    |
# | time/              |          |
# |    episodes        | 1244     |
# |    fps             | 156      |
# |    time_elapsed    | 3633     |
# |    total_timesteps | 567338   |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 5.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 557358   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | -91.9    |
# | time/              |          |
# |    episodes        | 1248     |
# |    fps             | 156      |
# |    time_elapsed    | 3635     |
# |    total_timesteps | 567646   |
# | train/             |          |
# |    actor_loss      | -35.7    |
# |    critic_loss     | 7.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 557681   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 394      |
# |    ep_rew_mean     | -94      |
# | time/              |          |
# |    episodes        | 1252     |
# |    fps             | 156      |
# |    time_elapsed    | 3637     |
# |    total_timesteps | 567873   |
# | train/             |          |
# |    actor_loss      | -35.3    |
# |    critic_loss     | 3.82     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 557907   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | -90.7    |
# | time/              |          |
# |    episodes        | 1256     |
# |    fps             | 156      |
# |    time_elapsed    | 3639     |
# |    total_timesteps | 568187   |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 9.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 558217   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | -90.6    |
# | time/              |          |
# |    episodes        | 1260     |
# |    fps             | 156      |
# |    time_elapsed    | 3640     |
# |    total_timesteps | 568484   |
# | train/             |          |
# |    actor_loss      | -34.8    |
# |    critic_loss     | 6.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 558482   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 1264     |
# |    fps             | 156      |
# |    time_elapsed    | 3644     |
# |    total_timesteps | 569359   |
# | train/             |          |
# |    actor_loss      | -35.1    |
# |    critic_loss     | 8.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 558830   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 332      |
# |    ep_rew_mean     | -76.7    |
# | time/              |          |
# |    episodes        | 1268     |
# |    fps             | 156      |
# |    time_elapsed    | 3661     |
# |    total_timesteps | 572249   |
# | train/             |          |
# |    actor_loss      | -36.5    |
# |    critic_loss     | 5.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 561493   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 347      |
# |    ep_rew_mean     | -72.5    |
# | time/              |          |
# |    episodes        | 1272     |
# |    fps             | 156      |
# |    time_elapsed    | 3681     |
# |    total_timesteps | 575547   |
# | train/             |          |
# |    actor_loss      | -38.7    |
# |    critic_loss     | 6.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 564541   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 390      |
# |    ep_rew_mean     | -77.3    |
# | time/              |          |
# |    episodes        | 1276     |
# |    fps             | 156      |
# |    time_elapsed    | 3711     |
# |    total_timesteps | 580774   |
# | train/             |          |
# |    actor_loss      | -43.2    |
# |    critic_loss     | 5.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 569260   |
# ---------------------------------

# %%
import os
video_dir = "."
video_name = "replay.mp4"
env_id = "BipedalWalker-v3"

generate_replay(
    model = model,
    eval_env=DummyVecEnv([lambda: Monitor(gym.make(env_id, render_mode="rgb_array"))]),
    video_length=1000,
    is_deterministic=True,
    local_path=os.path.join(video_dir, video_name)
)
# Out:
# Saving video to /tmp/tmpqkrtilmu/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpqkrtilmu/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpqkrtilmu/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpqkrtilmu/-step-0-to-step-1000.mp4
# Video saved to: ./replay.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('replay.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=600 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
from stable_baselines3.common.evaluation import evaluate_policy

eval_env = Monitor(gym.make("BipedalWalker-v3"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=-101.28 +/- 6.132709528811361
